# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/Capstone_Project'
# Out:
# original_data  original_data.zip

# %%
#!unzip '/content/drive/MyDrive/Capstone_Project/original_data.zip' -d '/content/drive/MyDrive/Capstone_Project/original_data'
# Out:
# Archive:  /content/drive/MyDrive/Capstone_Project/original_data.zip
#   inflating: /content/drive/MyDrive/Capstone_Project/original_data/B0013_0001.png
#   inflating: /content/drive/MyDrive/Capstone_Project/original_data/B0013_0001.txt
#   inflating: /content/drive/MyDrive/Capstone_Project/original_data/B0013_0002.png
#   inflating: /content/drive/MyDrive/Capstone_Project/original_data/B0013_0002.txt
#   inflating: /content/drive/MyDrive/Capstone_Project/original_data/B0013_0003.png
#   inflating: /content/drive/MyDrive/Capstone_Project/original_data/B0013_0003.txt
#   inflating: /content/drive/MyDrive/Capstone_Project/original_data/B0013_0004.png
#   inflating: /content/drive/MyDrive/Capstone_Project/original_data/B0013_0004.txt
#   inflating: /content/drive/MyDrive/Capstone_Project/original_data/B0013_0005.png
#   inflating: /content/drive/MyDrive/Capstone_Project/original_data/B0013_0005.txt
#   inflating: /content/drive/MyDrive/Capstone_Project/original_data/B0013_0006.png
# ...

# %%
#!git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/Capstone_Project/darknet' # YOLO uses darknet in the background
# Out:
# Cloning into '/content/drive/MyDrive/Capstone_Project/darknet'...
# remote: Enumerating objects: 15514, done.
# remote: Total 15514 (delta 0), reused 0 (delta 0), pack-reused 15514
# Receiving objects: 100% (15514/15514), 14.16 MiB | 8.19 MiB/s, done.
# Resolving deltas: 100% (10413/10413), done.
# Updating files: 100% (2058/2058), done.

# %%
# %cd /content/drive/MyDrive/Capstone_Project/darknet
# Out:
# /content/drive/MyDrive/Capstone_Project/darknet

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   946 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#  1147 |             if (iteration_old == 0)
# ...

# %%
# %cd /content/drive/MyDrive/Capstone_Project/
# Out:
# /content/drive/MyDrive/Capstone_Project

# %%
#!python original_data/creating-files-data-and-name.py

# %%
#!python original_data/creating-train-and-test-txt-files.py # splitting data into 70% training and 30% testing data

# %%
# %cd /content/drive/MyDrive/Capstone_Project/
# Out:
# /content/drive/MyDrive/Capstone_Project

# %%
# !darknet/darknet #Checking if compilation is correct
# Out:
# usage: darknet/darknet <function>

# %%
# !darknet/darknet detector train original_data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 321231, rewritten_bbox = 0.036422 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.861187), count: 6, class_loss = 0.001756, iou_loss = 0.081453, total_loss = 0.083209
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.873891), count: 2, class_loss = 0.018980, iou_loss = 0.012545, total_loss = 0.031525
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 321239, rewritten_bbox = 0.036421 %
# ...
